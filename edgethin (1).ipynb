# %%
import tensorflow as tf
import os
from tensorflow.keras.utils import normalize
import numpy as np
from patchify import patchify, unpatchify
import  cv2
from PIL import Image
from matplotlib import pyplot as plt

# %%
def get_image_source_list(source):
   l=os.listdir(source)
   return l
def return_slised_image(large_image):
  patches = patchify(large_image, (512, 512), step=480)  
  return patches

# %%
def get_train_images(patches,patches_target):
  x_train=[]
  y_train=[]
  for i in range(15):
    for j in range(15):
      x_train.append(patches[i][j])
      y_train.append(patches_target[i][j])
  return x_train,y_train

# %%
def get_train_test_data(l_target,l_data,source,target_source):
    x_train=[]
    y_train=[]
    x_test=[]
    y_test=[]
    for x in range(len(l_target)):
        x_image=cv2.imread(os.path.join(source,l_data[x]),0)
        y_image=cv2.imread(os.path.join(target_source,l_target[x]),0)
        x_patches=return_slised_image(x_image)
        y_patches=return_slised_image(y_image)
        l,s=get_train_images(x_patches,y_patches)
        if x<19:
            x_train=x_train+l
            y_train=y_train+s
        else:
            x_test=x_test+l
            y_test=y_test+s
    x_train=np.array(x_train)
    x_train=x_train/255.0
    y_train=np.array(y_train)
    y_train=y_train/255.0
    x_test=np.array(x_test)
    x_test=x_test/255.0
    y_test=np.array(y_test)
    y_test=y_test/255.0
    
    return x_train,x_test,y_train,y_test

# %%
target_source=r"C:\Users\youss\Downloads\CS\Mars_Crater_Segmentation_Dataset_02-32_km_radius\edge_thinner" #put the path for thr file of your target
l_target=get_image_source_list(target_source)
print(l_target)
# Out:
# ['thm_dir_N-30_000_-30_0_0_30_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_030_-30_0_30_60_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_060_-30_0_60_90_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_090_-30_0_90_120_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_120_-30_0_120_150_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_150_-30_0_150_180_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_180_-30_0_-180_-150_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_210_-30_0_-150_-120_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_240_-30_0_-120_-90_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_270_-30_0_-90_-60_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_300_-30_0_-60_-30_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_330_-30_0_-30_0_2_32_km_segrng_4_edge.png', 'thm_dir_N00_000_0_30_0_30_2_32_km_segrng_4_edge.png', 'thm_dir_N00_030_0_30_30_60_2_32_km_segrng_4_edge.png', 'thm_dir_N00_060_0_30_60_90_2_32_km_segrng_4_edge.png', 'thm_dir_N00_090_0_30_90_120_2_32_km_segrng_4_edge.png', 'thm_dir_N00_120_0_30_120_150_2_32_km_segrng_4_edge.png', 'thm_dir_N00_150_0_30_150_180_2_32_km_segrng_4_edge.png', 'thm_dir_N00_180_0_30_-180_-150_2_32_km_segrng_4_edge.png', 'thm_dir_N00_210_0_30_-150_-120_2_32_km_segrng_4_edge.png', 'thm_dir_N00_240_0_30_-120_-90_2_32_km_segrng_4_edge.png', 'thm_dir_N00_270_0_30_-90_-60_2_32_km_segrng_4_edge.png', 'thm_dir_N00_300_0_30_-60_-30_2_32_km_segrng_4_edge.png', 'thm_dir_N00_330_0_30_-30_0_2_32_km_segrng_4_edge.png']

# %%
print(sorted(l_target))
l_target=sorted(l_target)
# Out:
# ['thm_dir_N-30_000_-30_0_0_30_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_030_-30_0_30_60_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_060_-30_0_60_90_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_090_-30_0_90_120_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_120_-30_0_120_150_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_150_-30_0_150_180_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_180_-30_0_-180_-150_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_210_-30_0_-150_-120_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_240_-30_0_-120_-90_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_270_-30_0_-90_-60_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_300_-30_0_-60_-30_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_330_-30_0_-30_0_2_32_km_segrng_4_edge.png', 'thm_dir_N00_000_0_30_0_30_2_32_km_segrng_4_edge.png', 'thm_dir_N00_030_0_30_30_60_2_32_km_segrng_4_edge.png', 'thm_dir_N00_060_0_30_60_90_2_32_km_segrng_4_edge.png', 'thm_dir_N00_090_0_30_90_120_2_32_km_segrng_4_edge.png', 'thm_dir_N00_120_0_30_120_150_2_32_km_segrng_4_edge.png', 'thm_dir_N00_150_0_30_150_180_2_32_km_segrng_4_edge.png', 'thm_dir_N00_180_0_30_-180_-150_2_32_km_segrng_4_edge.png', 'thm_dir_N00_210_0_30_-150_-120_2_32_km_segrng_4_edge.png', 'thm_dir_N00_240_0_30_-120_-90_2_32_km_segrng_4_edge.png', 'thm_dir_N00_270_0_30_-90_-60_2_32_km_segrng_4_edge.png', 'thm_dir_N00_300_0_30_-60_-30_2_32_km_segrng_4_edge.png', 'thm_dir_N00_330_0_30_-30_0_2_32_km_segrng_4_edge.png']

# %%
print(l_target)
# Out:
# ['thm_dir_N-30_000_-30_0_0_30_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_030_-30_0_30_60_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_060_-30_0_60_90_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_090_-30_0_90_120_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_120_-30_0_120_150_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_150_-30_0_150_180_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_180_-30_0_-180_-150_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_210_-30_0_-150_-120_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_240_-30_0_-120_-90_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_270_-30_0_-90_-60_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_300_-30_0_-60_-30_2_32_km_segrng_4_edge.png', 'thm_dir_N-30_330_-30_0_-30_0_2_32_km_segrng_4_edge.png', 'thm_dir_N00_000_0_30_0_30_2_32_km_segrng_4_edge.png', 'thm_dir_N00_030_0_30_30_60_2_32_km_segrng_4_edge.png', 'thm_dir_N00_060_0_30_60_90_2_32_km_segrng_4_edge.png', 'thm_dir_N00_090_0_30_90_120_2_32_km_segrng_4_edge.png', 'thm_dir_N00_120_0_30_120_150_2_32_km_segrng_4_edge.png', 'thm_dir_N00_150_0_30_150_180_2_32_km_segrng_4_edge.png', 'thm_dir_N00_180_0_30_-180_-150_2_32_km_segrng_4_edge.png', 'thm_dir_N00_210_0_30_-150_-120_2_32_km_segrng_4_edge.png', 'thm_dir_N00_240_0_30_-120_-90_2_32_km_segrng_4_edge.png', 'thm_dir_N00_270_0_30_-90_-60_2_32_km_segrng_4_edge.png', 'thm_dir_N00_300_0_30_-60_-30_2_32_km_segrng_4_edge.png', 'thm_dir_N00_330_0_30_-30_0_2_32_km_segrng_4_edge.png']

# %%
source=r"C:\Users\youss\jupyter\tp ML\preprossed_data"  # put the preprocessing path 
l_data=get_image_source_list(source)
print(l_data)
# Out:
# ['thm_dir_N-30_000.pnggood_image.png', 'thm_dir_N-30_030.pnggood_image.png', 'thm_dir_N-30_060.pnggood_image.png', 'thm_dir_N-30_090.pnggood_image.png', 'thm_dir_N-30_120.pnggood_image.png', 'thm_dir_N-30_150.pnggood_image.png', 'thm_dir_N-30_180.pnggood_image.png', 'thm_dir_N-30_210.pnggood_image.png', 'thm_dir_N-30_240.pnggood_image.png', 'thm_dir_N-30_270.pnggood_image.png', 'thm_dir_N-30_300.pnggood_image.png', 'thm_dir_N-30_330.pnggood_image.png', 'thm_dir_N00_000.pnggood_image.png', 'thm_dir_N00_030.pnggood_image.png', 'thm_dir_N00_060.pnggood_image.png', 'thm_dir_N00_090.pnggood_image.png', 'thm_dir_N00_120.pnggood_image.png', 'thm_dir_N00_150.pnggood_image.png', 'thm_dir_N00_180.pnggood_image.png', 'thm_dir_N00_210.pnggood_image.png', 'thm_dir_N00_240.pnggood_image.png', 'thm_dir_N00_270.pnggood_image.png', 'thm_dir_N00_300.pnggood_image.png', 'thm_dir_N00_330.pnggood_image.png']

# %%
x_train,x_test,y_train,y_test = get_train_test_data(l_target,l_data,source,target_source)

# %%
l_target=None
l_data=None
source=None
target_source=None
# hadhom just bich irata7 iram imta3kim chwaya

# %%
from keras.models import Model, load_model
from keras.layers import Dense, Input, BatchNormalization, Dropout
from keras.layers import Add
from keras.layers.convolutional import Conv2D, MaxPooling2D, AveragePooling2D, UpSampling2D
from keras import backend as K
from keras import optimizers
from keras import metrics
import datetime
import glob
import random
from pandas import DataFrame

import numpy as np
import matplotlib.pyplot as plt

# %%
IMG_WIDTH = 512
IMG_HEIGHT = 512
IMG_CHANNELS = 1

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

# %%
checkpoint = ModelCheckpoint(r"C:\Users\youss\jupyter\tp ML\model_thin.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only=True,
                             verbose=1)

# EarlyStopping to find best model with a large number of epochs
earlystop = EarlyStopping(monitor='val_loss',
                          restore_best_weights=True,
                          patience=12,  # number of epochs with no improvement after which training will be stopped
                          verbose=1)

callbacks = [earlystop, checkpoint]

# %%
# model = new_unet()

# %%
def default_unet(): 
     z1 = Input(shape=(512,512,1))

     #Encoder path
     z2 = Conv2D(16, 3, padding='same', activation='relu')(z1)
     p2 = AveragePooling2D(pool_size=2)(z2)

     z3 = Conv2D(24, 3, padding='same', activation='relu')(p2)
     p3 = AveragePooling2D(pool_size=2)(z3)

     z4 = Conv2D(32, 3, padding='same', activation='relu')(p3)
     d4 = Dropout(0.2)(z4)
     p4 = AveragePooling2D(pool_size=2)(d4)

     z5 = Conv2D(48, 3, padding='same', activation='relu')(p4)
     d5 = Dropout(0.2)(z5)
     p5 = AveragePooling2D(pool_size=2)(d5)

     z6 = Conv2D(64, 3, padding='same', activation='relu')(p5)
     d6 = Dropout(0.2)(z6)
     p6 = AveragePooling2D(pool_size=2)(d6)

     z7 = Conv2D(96, 3, padding='same', activation='relu')(p6)
     d7 = Dropout(0.2)(z7)
     p7 = AveragePooling2D(pool_size=2)(d7)

     z8 = Conv2D(128, 3, padding='same', activation='relu')(p7)
     d8 = Dropout(0.2)(z8)
     p8 = AveragePooling2D(pool_size=2)(d8)

     z9 = Conv2D(128, 3, padding='same', activation='relu')(p8)
     d9 = Dropout(0.2)(z9)

     #Decoder path

     u9 = UpSampling2D(size=2)(d9)
     q9 = Conv2D(128, 3, padding='same', activation='relu')(u9)
     d9b = Dropout(0.2)(q9)
     a9 = Add()([d9b,z8])

     u8 = UpSampling2D(size=2)(a9)
     q8 = Conv2D(96, 3, padding='same', activation='relu')(u8)
     d8b = Dropout(0.2)(q8)
     a8 = Add()([d8b,z7])

     u7 = UpSampling2D(size=2)(a8)
     q7 = Conv2D(64, 3, padding='same', activation='relu')(u7)
     d7b = Dropout(0.2)(q7)
     a7 = Add()([d7b,z6])

     u6 = UpSampling2D(size=2)(a7)
     q6 = Conv2D(48, 3, padding='same', activation='relu')(u6)
     d6b = Dropout(0.2)(q6)
     a6 = Add()([d6b,z5])

     u5 = UpSampling2D(size=2)(a6)
     q5 = Conv2D(32, 3, padding='same', activation='relu')(u5)
     d5b = Dropout(0.2)(q5)
     a5 = Add()([d5b,z4])

     u4 = UpSampling2D(size=2)(a5)
     q4 = Conv2D(24, 3, padding='same', activation='relu')(u4)
     a4 = Add()([q4,z3])

     u3 = UpSampling2D(size=2)(a4)
     q3 = Conv2D(16, 3, padding='same', activation='relu')(u3)
     a3 = Add()([q3,z2])

     z_final = Conv2D(1, 3, padding='same', activation='sigmoid')(a3)

     #z8 activation = sigmoid or softmax

     model=Model(inputs = z1, outputs = z_final)
     model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
     return model

# %%
modell=default_unet()

# %%
resultss = modell.fit(x_train, y_train, validation_split=0.2, batch_size=16, epochs=100, callbacks=callbacks)
# Out:
# Epoch 1/100
# 214/214 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9760
# Epoch 1: val_loss improved from inf to 0.04545, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1172s 5s/step - loss: 0.1137 - accuracy: 0.9760 - val_loss: 0.0455 - val_accuracy: 0.9904
# Epoch 2/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0864 - accuracy: 0.9764
# Epoch 2: val_loss improved from 0.04545 to 0.04080, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1177s 5s/step - loss: 0.0864 - accuracy: 0.9764 - val_loss: 0.0408 - val_accuracy: 0.9896
# Epoch 3/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0790 - accuracy: 0.9775
# Epoch 3: val_loss improved from 0.04080 to 0.03947, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1123s 5s/step - loss: 0.0790 - accuracy: 0.9775 - val_loss: 0.0395 - val_accuracy: 0.9906
# Epoch 4/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0749 - accuracy: 0.9786
# Epoch 4: val_loss improved from 0.03947 to 0.03588, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1115s 5s/step - loss: 0.0749 - accuracy: 0.9786 - val_loss: 0.0359 - val_accuracy: 0.9914
# Epoch 5/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0716 - accuracy: 0.9793
# Epoch 5: val_loss improved from 0.03588 to 0.03392, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1121s 5s/step - loss: 0.0716 - accuracy: 0.9793 - val_loss: 0.0339 - val_accuracy: 0.9919
# Epoch 6/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0696 - accuracy: 0.9797
# Epoch 6: val_loss improved from 0.03392 to 0.03191, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1117s 5s/step - loss: 0.0696 - accuracy: 0.9797 - val_loss: 0.0319 - val_accuracy: 0.9921
# Epoch 7/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9801
# Epoch 7: val_loss improved from 0.03191 to 0.03076, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1111s 5s/step - loss: 0.0677 - accuracy: 0.9801 - val_loss: 0.0308 - val_accuracy: 0.9922
# Epoch 8/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0665 - accuracy: 0.9803
# Epoch 8: val_loss improved from 0.03076 to 0.03052, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1133s 5s/step - loss: 0.0665 - accuracy: 0.9803 - val_loss: 0.0305 - val_accuracy: 0.9923
# Epoch 9/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0650 - accuracy: 0.9805
# Epoch 9: val_loss improved from 0.03052 to 0.02997, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1207s 6s/step - loss: 0.0650 - accuracy: 0.9805 - val_loss: 0.0300 - val_accuracy: 0.9923
# Epoch 10/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0638 - accuracy: 0.9807
# Epoch 10: val_loss improved from 0.02997 to 0.02954, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1183s 6s/step - loss: 0.0638 - accuracy: 0.9807 - val_loss: 0.0295 - val_accuracy: 0.9924
# Epoch 11/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0632 - accuracy: 0.9808
# Epoch 11: val_loss did not improve from 0.02954
# 214/214 [==============================] - 1187s 6s/step - loss: 0.0632 - accuracy: 0.9808 - val_loss: 0.0296 - val_accuracy: 0.9924
# Epoch 12/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0620 - accuracy: 0.9810
# Epoch 12: val_loss improved from 0.02954 to 0.02950, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1221s 6s/step - loss: 0.0620 - accuracy: 0.9810 - val_loss: 0.0295 - val_accuracy: 0.9924
# Epoch 13/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9811
# Epoch 13: val_loss improved from 0.02950 to 0.02854, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1176s 5s/step - loss: 0.0616 - accuracy: 0.9811 - val_loss: 0.0285 - val_accuracy: 0.9926
# Epoch 14/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0610 - accuracy: 0.9812
# Epoch 14: val_loss improved from 0.02854 to 0.02822, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1215s 6s/step - loss: 0.0610 - accuracy: 0.9812 - val_loss: 0.0282 - val_accuracy: 0.9926
# Epoch 15/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0601 - accuracy: 0.9813
# Epoch 15: val_loss improved from 0.02822 to 0.02806, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1181s 6s/step - loss: 0.0601 - accuracy: 0.9813 - val_loss: 0.0281 - val_accuracy: 0.9926
# Epoch 16/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0595 - accuracy: 0.9814
# Epoch 16: val_loss did not improve from 0.02806
# 214/214 [==============================] - 1187s 6s/step - loss: 0.0595 - accuracy: 0.9814 - val_loss: 0.0281 - val_accuracy: 0.9927
# Epoch 17/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 0.9814
# Epoch 17: val_loss improved from 0.02806 to 0.02785, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1152s 5s/step - loss: 0.0591 - accuracy: 0.9814 - val_loss: 0.0278 - val_accuracy: 0.9926
# Epoch 18/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 0.9815
# Epoch 18: val_loss did not improve from 0.02785
# 214/214 [==============================] - 1225s 6s/step - loss: 0.0589 - accuracy: 0.9815 - val_loss: 0.0279 - val_accuracy: 0.9926
# Epoch 19/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9816
# Epoch 19: val_loss did not improve from 0.02785
# 214/214 [==============================] - 1344s 6s/step - loss: 0.0584 - accuracy: 0.9816 - val_loss: 0.0280 - val_accuracy: 0.9927
# Epoch 20/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9817
# Epoch 20: val_loss improved from 0.02785 to 0.02782, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1407s 7s/step - loss: 0.0575 - accuracy: 0.9817 - val_loss: 0.0278 - val_accuracy: 0.9927
# Epoch 21/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9817
# Epoch 21: val_loss improved from 0.02782 to 0.02710, saving model to C:\Users\youss\jupyter\tp ML\model_thin.h5
# 214/214 [==============================] - 1428s 7s/step - loss: 0.0575 - accuracy: 0.9817 - val_loss: 0.0271 - val_accuracy: 0.9928
# Epoch 22/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 0.9817
# Epoch 22: val_loss did not improve from 0.02710
# 214/214 [==============================] - 1344s 6s/step - loss: 0.0572 - accuracy: 0.9817 - val_loss: 0.0275 - val_accuracy: 0.9928
# Epoch 23/100
# 214/214 [==============================] - ETA: 0s - loss: 0.0564 - accuracy: 0.9818
# Epoch 23: val_loss did not improve from 0.02710
# 214/214 [==============================] - 1229s 6s/step - loss: 0.0564 - accuracy: 0.9818 - val_loss: 0.0272 - val_accuracy: 0.9928
# Epoch 24/100
# 113/214 [==============>...............] - ETA: 9:34 - loss: 0.0545 - accuracy: 0.9824
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 resultss = modell.fit(x_train, y_train, validation_split=0.2, batch_size=16, epochs=100, callbacks=callbacks)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
resultss =

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 13
#      10   plt.show()
#      12 # Plot the accuracy and results
# ---> 13 plot_graphs(model, "accuracy")
#      14 plot_graphs(model, "loss")
#
# Cell In[27], line 5, in plot_graphs(history, string)
#       4 def plot_graphs(history, string):
# ----> 5   plt.plot(history.history[string])
#       6   plt.plot(history.history['val_'+string])
#       7   plt.xlabel("Epochs")
#
# TypeError: 'History' object is not subscriptable

# %%
from tensorflow import keras

# %%
model = keras.models.load_model('./model_thin.h5')

# %%
testing_pred = model.predict(x_test)
# Out:
# 36/36 [==============================] - 74s 2s/step

# %%
testing = (testing_pred > 0.2).astype(np.uint8)

# %%
ix = random.randint(0, len(x_test))
ix =1119
plt.imshow(x_test[ix])
plt.show()
plt.imshow(np.squeeze(y_test[ix]))
plt.show()
plt.imshow(np.squeeze(testing[ix]))
plt.show()

# %%
print(ix)
# Out:
# 194

# %%
1119
1086
523
